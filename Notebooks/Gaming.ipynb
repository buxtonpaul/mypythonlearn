# %% [markdown]
# Zombies come around the corner and attack!
# ----

# %%
import random
r=random.SystemRandom()
def roll(rollstring):
    vals=rollstring.split('d')
    #print vals
    if(vals[0].isdigit()):
        count=int(vals[0])
    else:
        count=1
    sides=int(vals[1])
    print "Rolling %s Dd %s's result" %(count,sides)
    a=[random.randint(1,sides) for x in range(count)]
    sum=0
    print('Rattle....'),
    print a
    return a
 
roll('1d6')
roll('d100')
roll('2d6')
roll('2d6')
print sum(roll('4d8'))
# Out:
# Rolling 1 Dd 6's result
# Rattle.... [2]
# Rolling 1 Dd 100's result
# Rattle.... [15]
# Rolling 2 Dd 6's result
# Rattle.... [2, 2]
# Rolling 2 Dd 6's result
# Rattle.... [3, 1]
# Rolling 4 Dd 8's result
# Rattle.... [3, 8, 8, 1]
# 20

# %%
roll('1d6')
# Out:
# Rolling 1 Dd 6's result
# Rattle.... [3]
# [3]

# %%
roll ('d100')
# Out:
# Rolling 1 Dd 100's result
# Rattle.... [21]
# [21]

# %%
roll('2d6')
# Out:
# Rolling 2 Dd 6's result
# Rattle.... [2, 5]
# [2, 5]

# %%
from IPython.display import Image
Image('images/Screenshot.png')

# %% [markdown]
# ![alt text](images/Screenshot.png "Example on inlining an image in a notebook")
